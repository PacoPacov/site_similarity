# %%
import  json

with open("/home/paco/Documents/site_similarity/data/scrapping_results/processed level 1 results.json", 'r') as f:
    lvl_one_data = json.load(f)

# %%
len(lvl_one_data)
# Out:
# 1062

# %%
from pprint import pprint

pprint(lvl_one_data['villagevoice.com'])
# Out:
# {'amny.com': {'audience_geography': [{'country': 'United States',
#                                       'percent': 90.6},
#                                      {'country': 'Bangladesh', 'percent': 0.8}],
#               'score': [{'alexa_rank': 16740.0,
#                          'overlap_score': 15.2,
#                          'url': 'gothamist.com'},
#                         {'alexa_rank': 41637.0,
#                          'overlap_score': 14.9,
#                          'url': 'ny1.com'},
#                         {'alexa_rank': 17272.0,
#                          'overlap_score': 14.4,
#                          'url': 'abc7ny.com'},
#                         {'alexa_rank': 14853.0,
#                          'overlap_score': 13.8,
#                          'url': 'nbcnewyork.com'},
#                         {'alexa_rank': 52648.0,
#                          'overlap_score': 11.0,
#                          'url': 'pix11.com'}],
#               'site': 'amny.com'},
# ...

# %%
data = {
    "villagevoice.com": {
        "nylon.com": {
            "site": "nylon.com",
            "score": [
                {
                    "url": "compatible-astrology.com",
                    "overlap_score": 16.1,
                    "alexa_rank": 173807.0
                },
                {
                    "url": "astrology-zodiac-signs.com",
                    "overlap_score": 14.1,
                    "alexa_rank": 18913.0
                },
                {
                    "url": "papermag.com",
                    "overlap_score": 13.8,
                    "alexa_rank": 31762.0
                },
                {
                    "url": "astrology.com",
                    "overlap_score": 12.7,
                    "alexa_rank": 16859.0
                },
                {
                    "url": "flaunt.com",
                    "overlap_score": 11.1,
                    "alexa_rank": 10267.0
                }
            ],
            "audience_geography": [
                {
                    "country": "United States",
                    "percent": 75.0
                },
                {
                    "country": "Canada",
                    "percent": 4.8
                },
                {
                    "country": "India",
                    "percent": 2.3
                }
            ]
        },
        "slantmagazine.com": {
            "site": "slantmagazine.com",
            "score": [
                {
                    "url": "criterion.com",
                    "overlap_score": 11.3,
                    "alexa_rank": 38257.0
                },
                {
                    "url": "rogerebert.com",
                    "overlap_score": 5.2,
                    "alexa_rank": 13105.0
                },
                {
                    "url": "empireonline.com",
                    "overlap_score": 4.6,
                    "alexa_rank": 37046.0
                },
                {
                    "url": "dvdbeaver.com",
                    "overlap_score": 4.6,
                    "alexa_rank": 291202.0
                },
                {
                    "url": "letterboxd.com",
                    "overlap_score": 4.2,
                    "alexa_rank": 2817.0
                }
            ],
            "audience_geography": [
                {
                    "country": "United States",
                    "percent": 54.8
                },
                {
                    "country": "Canada",
                    "percent": 7.4
                },
                {
                    "country": "India",
                    "percent": 6.2
                }
            ]
        },
        "gothamist.com": {
            "site": "gothamist.com",
            "score": [
                {
                    "url": "nbcnewyork.com",
                    "overlap_score": 18.3,
                    "alexa_rank": 14853.0
                },
                {
                    "url": "abc7ny.com",
                    "overlap_score": 17.5,
                    "alexa_rank": 17272.0
                },
                {
                    "url": "ny1.com",
                    "overlap_score": 15.2,
                    "alexa_rank": 41637.0
                },
                {
                    "url": "nyc.gov",
                    "overlap_score": 15.2,
                    "alexa_rank": 2881.0
                },
                {
                    "url": "amny.com",
                    "overlap_score": 15.2,
                    "alexa_rank": 69870.0
                }
            ],
            "audience_geography": [
                {
                    "country": "United States",
                    "percent": 93.8
                },
                {
                    "country": "Canada",
                    "percent": 1.0
                },
                {
                    "country": "India",
                    "percent": 0.5
                }
            ]
        },
        "screendaily.com": {
            "site": "screendaily.com",
            "score": [
                {
                    "url": "cineuropa.org",
                    "overlap_score": 15.7,
                    "alexa_rank": 68374.0
                },
                {
                    "url": "theplaylist.net",
                    "overlap_score": 5.6,
                    "alexa_rank": 65383.0
                },
                {
                    "url": "boxofficemojo.com",
                    "overlap_score": 5.4,
                    "alexa_rank": 14132.0
                },
                {
                    "url": "moviemeter.nl",
                    "overlap_score": 5.2,
                    "alexa_rank": 215832.0
                },
                {
                    "url": "letterboxd.com",
                    "overlap_score": 5.0,
                    "alexa_rank": 2817.0
                }
            ],
            "audience_geography": [
                {
                    "country": "United States",
                    "percent": 19.6
                },
                {
                    "country": "India",
                    "percent": 9.8
                },
                {
                    "country": "Canada",
                    "percent": 4.3
                }
            ]
        },
        "amny.com": {
            "site": "amny.com",
            "score": [
                {
                    "url": "gothamist.com",
                    "overlap_score": 15.2,
                    "alexa_rank": 16740.0
                },
                {
                    "url": "ny1.com",
                    "overlap_score": 14.9,
                    "alexa_rank": 41637.0
                },
                {
                    "url": "abc7ny.com",
                    "overlap_score": 14.4,
                    "alexa_rank": 17272.0
                },
                {
                    "url": "nbcnewyork.com",
                    "overlap_score": 13.8,
                    "alexa_rank": 14853.0
                },
                {
                    "url": "pix11.com",
                    "overlap_score": 11.0,
                    "alexa_rank": 52648.0
                }
            ],
            "audience_geography": [
                {
                    "country": "United States",
                    "percent": 90.6
                },
                {
                    "country": "Bangladesh",
                    "percent": 0.8
                }
            ]
        }
    }}

# pprint(data)

from dataprep.alexa_scrapper import ScrapeAlexa

alexa_scrapper = ScrapeAlexa()
for c in data.values():
    # pprint(c)
    for cc in c.values():
        print(cc['site'], cc['score'])
        for overlap_site in cc.get('score', []):
            pprint(alexa_scrapper.scrape_alexa_site_info(overlap_site['url']))
        # pprint({overlap_site['url']: alexa_scrapper.scrape_alexa_site_info(overlap_site['url'])
        #                                   for overlap_site in cc.get('score', [])})
# Out:
# nylon.com [{'url': 'compatible-astrology.com', 'overlap_score': 16.1, 'alexa_rank': 173807.0}, {'url': 'astrology-zodiac-signs.com', 'overlap_score': 14.1, 'alexa_rank': 18913.0}, {'url': 'papermag.com', 'overlap_score': 13.8, 'alexa_rank': 31762.0}, {'url': 'astrology.com', 'overlap_score': 12.7, 'alexa_rank': 16859.0}, {'url': 'flaunt.com', 'overlap_score': 11.1, 'alexa_rank': 10267.0}]
# {'audience_geography': [{'country': 'United States', 'percent': 41.7},
#                         {'country': 'India', 'percent': 23.6},
#                         {'country': 'Pakistan', 'percent': 6.9}],
#  'score': [{'alexa_rank': 18913.0,
#             'overlap_score': 65.8,
#             'url': 'astrology-zodiac-signs.com'},
#            {'alexa_rank': 16859.0,
#             'overlap_score': 49.4,
#             'url': 'astrology.com'},
#            {'alexa_rank': 1078304.0,
#             'overlap_score': 38.4,
#             'url': 'astromatcha.com'},
#            {'alexa_rank': 13405.0,
# ...

# %%
from dataprep.alexa_scrapper import scrapping

results = scrapping(lvl_one_data, target_dir='/home/paco/Documents/site_similarity/data/level 2 scrapping/')
# Out:
# 100%|██████████| 1062/1062 [1:06:26<00:00,  3.75s/it]

# %%
len(results)
# Out:
# 3560

# %% [markdown]
# # Check the result data

# %%
# Look for empty elements
[res for result in results.values() for res in result.values() if res['score'] is None]
# Out:
# [{'site': 'open-britain.co.uk', 'score': None, 'audience_geography': []},
#  {'site': 'gunsinternational.com', 'score': None, 'audience_geography': []},
#  {'site': 'miamigov.com', 'score': None, 'audience_geography': []}]

# %%
# Distribution of the results length

from collections import Counter

Counter([len(res['score']) for result in results.values() for res in result.values()])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-badc4cdd5336> in <module>
#       3 from collections import Counter
#       4
# ----> 5 Counter([len(res['score']) for result in results.values() for res in result.values()])
#       6
#
# <ipython-input-12-badc4cdd5336> in <listcomp>(.0)
#       3 from collections import Counter
#       4
# ----> 5 Counter([len(res['score']) for result in results.values() for res in result.values()])
#       6
#
# TypeError: object of type 'NoneType' has no len()

# %%
# Records with no Audience overlap

[res for result in results.values() for res in result.values() if len(res['score']) == 0]

# %% [markdown]
# # Save results from scrapping level 2

# %%
import json

with open("/home/paco/Documents/site_similarity/data/scrapping_results/processed level 2 results.json", 'w') as f:
    json.dump(results, f, indent=4)
