# %%
import sys
sys.path.append("/home/paco/Documents/site_similarity")

# %%
from utils.notebook_utils import train_model, load_node2vec_model
from sklearn.linear_model import LogisticRegressionCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import svm


models = [
    'corpus_2020_unweighted_lvl_one_64D.model',
    'corpus_2020_unweighted_lvl_one_128D.model',
    'corpus_2020_weighted_lvl_one_64D.model',
    'corpus_2020_weighted_lvl_one_128D.model'
]


for model in models:
    print(f'Using model: {model}')
    node2vec_model = load_node2vec_model(model)

    clf = LogisticRegressionCV(
        Cs=10, cv=5, scoring="accuracy", multi_class="ovr", max_iter=300, random_state=42
    )
    train_model(clf, node2vec_model=node2vec_model, data_year='2020')


    clf2 = LogisticRegressionCV(
        Cs=10, cv=10, scoring="accuracy", multi_class="ovr", max_iter=300, random_state=42
    )
    train_model(clf2, node2vec_model=node2vec_model, data_year='2020')

    tree_clf = GradientBoostingClassifier(random_state=42)
    train_model(tree_clf, node2vec_model=node2vec_model, data_year='2020')

    svm_clf = svm.SVC(decision_function_shape='ovo', probability=True) 
    train_model(svm_clf, node2vec_model=node2vec_model, data_year='2020')
# Out:
# Using model: corpus_2020_unweighted_lvl_one_64D.model
# Start training...
# Accuracy: 56.461001164144356
# Macro-F1: 36.27700708111292
# Flip Error-rate: 14.668218859138532
# MAE: 0.5820721769499418
# Start training...
# Accuracy: 56.57741559953434
# Macro-F1: 38.12281960739985
# Flip Error-rate: 13.969732246798602
# MAE: 0.5739231664726426
# Start training...
# Accuracy: 60.41909196740396
# Macro-F1: 49.047676989704755
# Flip Error-rate: 10.360884749708964
# MAE: 0.49941792782305006
# Start training...
# Accuracy: 63.329452852153665
# Macro-F1: 50.691399181380184
# Flip Error-rate: 9.89522700814901
# MAE: 0.46565774155995343
# Using model: corpus_2020_unweighted_lvl_one_128D.model
# Start training...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-bb468a264c35> in <module>
#      20         Cs=10, cv=5, scoring="accuracy", multi_class="ovr", max_iter=300, random_state=42
#      21     )
# ---> 22     train_model(clf, node2vec_model=node2vec_model, data_year='2020')
#      23
#      24
#
# ~/Documents/site_similarity/utils/notebook_utils.py in train_model(clf, node2vec_model, data_year, num_labels)
#     120
#     121         # train the classifier
# --> 122         clf.fit(X["train"], y["train"])
#     123
#     124         # generate predictions
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1897                       l1_ratio=l1_ratio
#    1898                       )
# -> 1899             for label in iter_encoded_labels
#    1900             for train, test in folds
#    1901             for l1_ratio in l1_ratios_)
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/joblib/parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/joblib/parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py in _log_reg_scoring_path(X, y, train, test, pos_class, Cs, scoring, fit_intercept, max_iter, tol, class_weight, verbose, solver, penalty, dual, intercept_scaling, multi_class, random_state, max_squared_sum, sample_weight, l1_ratio)
#     970         penalty=penalty, intercept_scaling=intercept_scaling,
#     971         random_state=random_state, check_input=False,
# --> 972         max_squared_sum=max_squared_sum, sample_weight=sample_weight)
#     973
#     974     log_reg = LogisticRegression(solver=solver, multi_class=multi_class)
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     758                 func, w0, method="L-BFGS-B", jac=True,
#     759                 args=(X, target, 1. / C, sample_weight),
# --> 760                 options={"iprint": iprint, "gtol": tol, "maxiter": max_iter}
#     761             )
#     762             n_iter_i = _check_optimize_result(
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     616     elif meth == 'l-bfgs-b':
#     617         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 618                                 callback=callback, **options)
#     619     elif meth == 'tnc':
#     620         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/scipy/optimize/optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py in _logistic_loss_and_grad(w, X, y, alpha, sample_weight)
#     120
#     121     # Logistic loss is the negative of the log of the logistic function.
# --> 122     out = -np.sum(sample_weight * log_logistic(yz)) + .5 * alpha * np.dot(w, w)
#     123
#     124     z = expit(yz)
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/sklearn/utils/extmath.py in log_logistic(X, out)
#     574     is_1d = X.ndim == 1
#     575     X = np.atleast_2d(X)
# --> 576     X = check_array(X, dtype=np.float64)
#     577
#     578     n_samples, n_features = X.shape
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     647
#     648     if ensure_min_samples > 0:
# --> 649         n_samples = _num_samples(array)
#     650         if n_samples < ensure_min_samples:
#     651             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#
# ~/.conda/envs/site_similarity/lib/python3.6/site-packages/sklearn/utils/validation.py in _num_samples(x)
#     181 def _num_samples(x):
#     182     """Return number of samples in array-like x."""
# --> 183     message = 'Expected sequence or array-like, got %s' % type(x)
#     184     if hasattr(x, 'fit') and callable(x.fit):
#     185         # Don't get num_samples from an ensembles length!
#
# KeyboardInterrupt:
